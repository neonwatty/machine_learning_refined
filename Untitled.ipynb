# %%
# load in subdirectories containing python files
import sys
sys.path.append('python_files')

# %%
# import class for visualizing complete function approximation
from Function_Fit_Demo1 import Fit_Bases
# %matplotlib inline
func_fit = Fit_Bases()
func_fit.load_target('datasets/steppy_func.csv')
func_fit.browse_cos_fit()

# %%
s

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
r = np.linspace(0,1,300)[:, np.newaxis]
f = make_cos_approx(r,10)
w = np.random.randn(np.shape(f)[1],1)
t = np.dot(f,w)
plt.plot(r,t)

# %%
plt.plot(r,t)

# %%
import pandas as pd
def save_signal(i,o,filename):
    data3 = np.concatenate([i,o],axis = 1)
    d = pd.DataFrame(data3,index = None)
    d.to_csv(filename,index = None, header = False)

# %%
save_signal(r,t,'simple_signal_3.csv')

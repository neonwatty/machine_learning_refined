# %% [markdown]
# # kernel and neural net space warping demos
#
# These slider toys shows how kernels and neural networks warp the underlying space of a dataset to tackle a prototypical nonlinear classification problem.  With these demonstrations you can play around and make any sort of nonlinear transformation rules you want and see how they warp space!
#
# This manner of visualizing how a neural network / kernel warps its input space complements the function or basis-view of neural networks described in Chapters 5-7 of the text.  The space is legally warped so that - in the transformed space - the two classes become linearly separable.
# This is a fundamental concept: nonlinear separation in the original data space corresponds one-to-one with linear separation in the transformed feature space (as illustrated in e.g., example 4.7 of the text).
#
# >The content of this notebook is supplementary material for the textbook Machine Learning Refined (Cambridge University Press, 2016). Visit http://www.mlrefined.com for free chapter downloads and tutorials, and [our Amazon site here](https://www.amazon.com/Machine-Learning-Refined-Foundations-Applications/dp/1107123526/ref=sr_1_1?ie=UTF8&qid=1474491657&sr=8-1&keywords=machine+learning+refined) for details regarding a hard copy of the text.
#
# Make sure to run the first Python cell below to load in all the necessary libraries for this demonstration.

# %%
# a necessary library for writing out our transform rules mathematically
from sympy import symbols, lambdify, sin, cos, tanh, exp, log, Max, Piecewise, And
from ipywidgets import interact
import sys
sys.path.append('demo_python_backend_files')

# our home-made warper 
import new_warper as warper
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="459bb79f-2ec0-47f4-89a5-8173ffa16ee2">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Space warping with a kernel
#
# Run the Python cells below to see how a basic kernel warps the underlying space of a dataset in order to correctly determine nonlinear separation.
#
# *Slowly* move this slider from left to right to see how the underlying space of this dataset is warped.  Gridlines are plotted in light gray to help you keep track of the transformations taking place.  Pushing the slider all the way to the right will show the complete transformation - in this space the dataset is perfectly linearly separable.
#
# **Note:** if you are not using a Docker image of this repo make sure you have installed the [bokeh](http://bokeh.pydata.org/en/latest/) plotting library in order to see this slider animation.

# %%
# make instance of warper
demo1 = warper.warp_demo()
x1,x2 = symbols('x1 x2')

# define your own rules here using elementary functions like sin, cos, tanh, sinc, or any polynomial combination of x1 and x2
rule1 = x1*x1 - 4
rule2 = x2*x2 - 4

# these two lines feed the transformation rules into the warping function and produce a toy dataset based on them
demo1.define_rule(rule1,rule2)
demo1.make_pts()

# this line creates an instance of the slider -  if you do not have bokeh installed you can use the demo1.transformation_slider - this uses matplotlib as the backend (and is considerably slower)
slider1 = demo1.bokeh_transformation_slider()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7e2f6f37-83f7-4ca7-a922-476e5fca4525"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7e2f6f37-83f7-4ca7-a922-476e5fca4525").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("bdce00cd-20d6-4697-9912-26dc8083c968", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7e2f6f37-83f7-4ca7-a922-476e5fca4525");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7e2f6f37-83f7-4ca7-a922-476e5fca4525' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9dc38373-2b12-43ad-9b9d-d6681f4d3003":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"372a6622-6e1b-458f-9bb8-b2a720ebe342","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"372a6622-6e1b-458f-9bb8-b2a720ebe342","type":"BoxAnnotation"},"plot":{"id":"99f623ca-3dbe-4179-a5b8-8aa00873fba3","subtype":"Figure","type":"Plot"}},"id":"c70003a6-a6bf-4269-b614-d5ba05b206d8","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":5.2,"start":-5.2},"id":"b000f88c-a703-476b-94d4-27299ab767e2","type":"Range1d"},{"attributes":{"data_source":{"id":"48dd2273-eef3-440f-b394-d43e68174597","type":"ColumnDataSource"},"glyph":{"id":"38994e9b-2ec2-4920-8996-8bbdc7f3d601","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"bd3e1dad-b007-4dcf-8ef0-60fc03f8e62a","type":"MultiLine"},"selection_glyph":null},"id":"63b0bd2b-6157-4c61-aa79-86b654620cf8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[144]},"y":{"__ndarray__":"...","dtype":"float64","shape":[144]}}},"id":"dd4f1603-c540-49da-ae63-f14fb5abcd43","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#00FF7F"},"line_color":{"value":"#000000"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"267bd20e-09ea-4a2d-9720-204a8281585e","type":"Circle"},{"attributes":{"formatter":{"id":"33bc5f60-6438-4266-9319-9b545de92a85","type":"BasicTickFormatter"},"plot":{"id":"99f623ca-3dbe-4179-a5b8-8aa00873fba3","subtype":"Figure","type":"Plot"},"ticker":{"id":"a4ddd81f-6753-47de-8e24-3d86765d05a2","type":"BasicTicker"},"visible":false},"id":"f662e355-7e8c-4326-83b7-2ebee4adf44e","type":"LinearAxis"},{"attributes":{},"id":"4fc05868-83ee-4af1-8051-55abd4c22774","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"99f623ca-3dbe-4179-a5b8-8aa00873fba3","subtype":"Figure","type":"Plot"}},"id":"24d3da5a-4805-4c4a-b75f-e018df3971c2","type":"PanTool"},{"attributes":{"callback":null,"column_names":["ys","xs"],"data":{"xs":[{"__ndarray__":"...","dtype":"float64","shape":[561]}],"ys":[{"__ndarray__":"...","dtype":"float64","shape":[561]}]}},"id":"48dd2273-eef3-440f-b394-d43e68174597","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#000000"},"line_width":{"value":5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"38994e9b-2ec2-4920-8996-8bbdc7f3d601","type":"MultiLine"},{"attributes":{"plot":{"id":"99f623ca-3dbe-4179-a5b8-8aa00873fba3","subtype":"Figure","type":"Plot"}},"id":"2495b2fb-8ed3-49a3-bc63-40dfed7b20b4","type":"SaveTool"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"99f623ca-3dbe-4179-a5b8-8aa00873fba3","subtype":"Figure","type":"Plot"},"ticker":{"id":"5506d252-552e-4037-bd5b-11d9ef9a35c0","type":"BasicTicker"}},"id":"7fc7891b-98a5-4308-bdd0-7521d3f6f935","type":"Grid"},{"attributes":{"formatter":{"id":"4fc05868-83ee-4af1-8051-55abd4c22774","type":"BasicTickFormatter"},"plot":{"id":"99f623ca-3dbe-4179-a5b8-8aa00873fba3","subtype":"Figure","type":"Plot"},"ticker":{"id":"5506d252-552e-4037-bd5b-11d9ef9a35c0","type":"BasicTicker"},"visible":false},"id":"220f052c-2025-44dc-993a-656125252e09","type":"LinearAxis"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"99f623ca-3dbe-4179-a5b8-8aa00873fba3","subtype":"Figure","type":"Plot"},"ticker":{"id":"a4ddd81f-6753-47de-8e24-3d86765d05a2","type":"BasicTicker"}},"id":"031b3f39-fcec-4362-96bb-bd88a9ccc76c","type":"Grid"},{"attributes":{},"id":"5506d252-552e-4037-bd5b-11d9ef9a35c0","type":"BasicTicker"},{"attributes":{"below":[{"id":"f662e355-7e8c-4326-83b7-2ebee4adf44e","type":"LinearAxis"}],"left":[{"id":"220f052c-2025-44dc-993a-656 ...

# %%
# activate your slider!
interact(slider1, param=(0,750,1))
# Out:
# <function new_warper.browse_vals>

# %% [markdown]
# You can view still images of the before and after shots from your transformation by activating the next Python cell.

# %%
# show the before and after shots from your transformation
demo1.show_before_and_after()

# %% [markdown]
# # Space warping with a neural network
#
# Run the Python cells below to see how a basic neural net warps the underlying space of a dataset in order to correctly determine nonlinear separation.
#
# *Slowly* move this slider from left to right to see how the underlying space of this dataset is warped.  Gridlines are plotted in light gray to help you keep track of the transformations taking place.  Pushing the slider all the way to the right will show the complete transformation - in this space the dataset is perfectly linearly separable.
#
# **Note:** if you are not using a Docker image of this repo make sure you have installed the [bokeh](http://bokeh.pydata.org/en/latest/) plotting library in order to see this slider animation.

# %%
# make instance of warper
demo2 = warper.warp_demo()
x1,x2 = symbols('x1 x2')

# define your own rules here using elementary functions like sin, cos, tanh, sinc, or any polynomial combination of x1 and x2
rule1 = tanh(x1 + x2 + tanh(x1))
rule2 = tanh(0.1*x1)

# these two lines feed the transformation rules into the warping function and produce a toy dataset based on them
demo2.define_rule(rule1,rule2)
demo2.make_pts()

# this line creates an instance of the slider -  if you do not have bokeh installed you can use the demo1.transformation_slider - this uses matplotlib as the backend (and is considerably slower)
slider2 = demo2.bokeh_transformation_slider()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="deb76a10-7543-4c42-bed5-ecd7c388becf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("deb76a10-7543-4c42-bed5-ecd7c388becf").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("1580232f-2e2f-4dea-8150-126b13b4dbb4", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("deb76a10-7543-4c42-bed5-ecd7c388becf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'deb76a10-7543-4c42-bed5-ecd7c388becf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2c6777e1-1abd-4188-97f2-7cb55cd26fe2":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7093b06d-7a97-46c2-a45e-bcc1891e35b5","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"e88f5758-fc98-4297-864f-22efac0e794a","subtype":"Figure","type":"Plot"}},"id":"afc04c87-8629-4dd9-a6f8-4f7ef06a8006","type":"SaveTool"},{"attributes":{"below":[{"id":"247c29c5-add1-44ed-b02b-cc8b671a4714","type":"LinearAxis"}],"left":[{"id":"82cba3ee-d288-4e86-a160-b9028a2f5888","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"247c29c5-add1-44ed-b02b-cc8b671a4714","type":"LinearAxis"},{"id":"4767703a-fe1a-49ad-bece-8755cac6aff0","type":"Grid"},{"id":"82cba3ee-d288-4e86-a160-b9028a2f5888","type":"LinearAxis"},{"id":"74d19f29-54cf-4f3f-8f74-4cfeb3a244fb","type":"Grid"},{"id":"7093b06d-7a97-46c2-a45e-bcc1891e35b5","type":"BoxAnnotation"},{"id":"2908c879-4cd3-4677-a1bd-10fa7b700256","type":"GlyphRenderer"},{"id":"ffed0987-6d6b-4c94-9129-be5468114f60","type":"GlyphRenderer"},{"id":"6f4008c1-0969-4f0f-a79d-94de78b0427e","type":"GlyphRenderer"},{"id":"ba2475b7-cecc-427b-9e43-492d5b97a028","type":"GlyphRenderer"}],"title":{"id":"f2a2f6be-0b6b-401d-a3c7-d5aa2cda4358","type":"Title"},"tool_events":{"id":"3e06ef7d-3113-4d52-abb8-ae7b9e9cc798","type":"ToolEvents"},"toolbar":{"id":"ed89299c-0b3f-45d9-8d47-fe46539ee6c0","type":"Toolbar"},"x_range":{"id":"5252308a-63a5-4eb6-9e53-edc061578b97","type":"Range1d"},"y_range":{"id":"e128eea7-7afb-478a-9a46-f55bf3522cdb","type":"Range1d"}},"id":"e88f5758-fc98-4297-864f-22efac0e794a","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#000000"},"line_width":{"value":5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"7b31a839-1119-4af4-942e-38bed312466c","type":"MultiLine"},{"attributes":{"data_source":{"id":"2243d529-a85c-4a3c-b8f5-6f369e1686a5","type":"ColumnDataSource"},"glyph":{"id":"83a28971-dd71-4e5e-8be7-30551dc22eba","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"5790c0fc-aec8-4142-99f8-b1d510e0e70c","type":"MultiLine"},"selection_glyph":null},"id":"2908c879-4cd3-4677-a1bd-10fa7b700256","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1303583c-cc07-4123-945d-9e0669cab304","type":"ColumnDataSource"},"glyph":{"id":"bf4a8bac-22b6-4c29-87bc-e394668ef35e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"3efe957e-1029-433a-9c80-cc5e2f81b87a","type":"Circle"},"selection_glyph":null},"id":"ffed0987-6d6b-4c94-9129-be5468114f60","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"20629f3a-a66f-4f19-8ac0-7f8a1dcb4266","type":"BasicTickFormatter"},"plot":{"id":"e88f5758-fc98-4297-864f-22efac0e794a","subtype":"Figure","type":"Plot"},"ticker":{"id":"04e85434-20e1-4901-a470-3619f8cb1f32","type":"BasicTicker"},"visible":false},"id":"247c29c5-add1-44ed-b02b-cc8b671a4714","type":"LinearAxis"},{"attributes":{"plot":{"id":"e88f5758-fc98-4297-864f-22efac0e794a","subtype":"Figure","type":"Plot"}},"id":"8b745361-796d-4a16-86e2-782dcf38e7f9","type":"PanTool"},{"attributes":{"callback":null,"column_names":["ys","xs"],"data":{"xs":[{"__ndarray__":"...","dtype":"float64","shape":[908]}],"ys":[{"__ndarray__":"...","dtype":"float64","shape":[908]}]}},"id":"62b0db98-dfa6-457d-a7ff-cc45b925f272","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"e88f5758-fc98-4297-864f-22efac0e794a","subtype":"Figure","type":"Plot"}},"id":"37ee7d07-d204-4678-8ab5-46ce88bd0e1e","type":"ResetTool"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"e88f5758-fc98-4297-864f-22efac0e794a","subtype":"Figure","type":"Plot"},"ticker":{"id":"de497e85-eae1-48b3-a673-fcd3e4f2aa96","type":"BasicTicker"}},"id":"74d19f29-54cf-4f ...

# %%
# activate your slider!
interact(slider2, param=(0,750,1))

# %% [markdown]
# You can view still images of the before and after shots from your transformation by activating the next Python cell.

# %%
# show the before and after shots from your transformation
demo2.show_before_and_after()

# %% [markdown]
# # BONUS SECTION: Space warping with a tree
#
# Run the Python cells below to see how a basic tree warps the underlying space of a dataset in order to correctly determine nonlinear separation.  This one can get quite crazy due to the way we are plotting the transformations!
#
# *Slowly* move this slider from left to right to see how the underlying space of this dataset is warped.  Gridlines are plotted in light gray to help you keep track of the transformations taking place.  Pushing the slider all the way to the right will show the complete transformation - in this space the dataset is perfectly linearly separable.
#
# **Note:** if you are not using a Docker image of this repo make sure you have installed the [bokeh](http://bokeh.pydata.org/en/latest/) plotting library in order to see this slider animation.

# %%
# make instance of warper
demo3 = warper.warp_demo()
x1,x2 = symbols('x1 x2')

# define your own rules here using elementary functions like sin, cos, tanh, sinc, or any polynomial combination of x1 and x2
rule1 = Piecewise(
    (-1, And(-1 < x1, x1 < 1)),
    (1, x1 > 1),
    (1, x1 < -1)
)
rule2 = Piecewise(
    (-1,And(-1 < x2, x2 < 1)),
    (1, x2 > 1),
    (1, x2 < -1)
)

# these two lines feed the transformation rules into the warping function and produce a toy dataset based on them
demo3.define_rule(rule1,rule2)
demo3.make_pts()

# this line creates an instance of the slider -  if you do not have bokeh installed you can use the demo1.transformation_slider - this uses matplotlib as the backend (and is considerably slower)
slider3 = demo3.bokeh_transformation_slider()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5b9cb693-17d0-4325-8f65-5bf79458847a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5b9cb693-17d0-4325-8f65-5bf79458847a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("f0f38d92-877b-40b2-bb51-9fba309706ab", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b9cb693-17d0-4325-8f65-5bf79458847a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b9cb693-17d0-4325-8f65-5bf79458847a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"51ea44ed-bcef-44be-bef2-a3caefed3d27":{"roots":{"references":[{"attributes":{"data_source":{"id":"5dce72a5-c0ac-41a9-92b3-e9095160cdb9","type":"ColumnDataSource"},"glyph":{"id":"b62565f1-6bc3-40dc-872f-f777678a7976","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"8cebd3b9-4a80-48d4-81a9-4b48e234de21","type":"MultiLine"},"selection_glyph":null},"id":"8e15f97b-f565-42e3-b1d2-424585f18086","type":"GlyphRenderer"},{"attributes":{},"id":"e8c878b2-0ce3-4ea6-8f62-4066c73b8a99","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"fe11ef5c-c729-4c87-90f8-34fd82e87ff9","type":"ColumnDataSource"},"glyph":{"id":"29d62d3d-5031-4fb3-a810-1cb713de2d59","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"6c6a0957-0b70-4bbf-9479-495b654b4ff5","type":"MultiLine"},"selection_glyph":null},"id":"4f3a43e6-bd48-423d-8aa9-1853c0477e5d","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#FF0080"},"line_color":{"value":"#000000"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"70d8e7f2-b760-412d-8fa1-dbfb56522408","type":"Circle"},{"attributes":{"plot":{"id":"e47804bd-4856-4f26-b001-dddf831c6c91","subtype":"Figure","type":"Plot"}},"id":"458fa81d-20bb-4fbf-adb6-27400071c8d0","type":"HelpTool"},{"attributes":{},"id":"75e6ca06-288c-4974-acf2-0703ab6451ac","type":"ToolEvents"},{"attributes":{"line_color":{"value":"#000000"},"line_width":{"value":5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"29d62d3d-5031-4fb3-a810-1cb713de2d59","type":"MultiLine"},{"attributes":{},"id":"40a91e3c-1174-4731-a780-6814e1c645d2","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"bd277d96-84c2-4eb4-8371-696140b97d58","type":"ColumnDataSource"},"glyph":{"id":"ca22de7d-e332-416b-8dd9-22b3457f0874","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"b9d0289a-19bb-4c8d-9b68-7646a5f67e40","type":"Circle"},"selection_glyph":null},"id":"e6964796-ab52-4634-abb6-dce5062db5f5","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e47804bd-4856-4f26-b001-dddf831c6c91","subtype":"Figure","type":"Plot"}},"id":"c4a0bd63-351a-4b72-87c2-b62ba53533cc","type":"PanTool"},{"attributes":{"formatter":{"id":"e8c878b2-0ce3-4ea6-8f62-4066c73b8a99","type":"BasicTickFormatter"},"plot":{"id":"e47804bd-4856-4f26-b001-dddf831c6c91","subtype":"Figure","type":"Plot"},"ticker":{"id":"07f22a88-96dd-4b67-acca-4bc2f6cdab32","type":"BasicTicker"},"visible":false},"id":"09bab45a-d10b-40ea-a569-28df6af179f0","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["ys","xs"],"data":{"xs":[{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]}],"ys":[{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]}]}},"id":"fe11ef5c-c729-4c87-90f8-34fd82e87ff9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"b9d0289a-19bb-4c8d-9b68-7646a5f67e40","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"78421680-927b-4b13-998d-8090b4c55043","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c4a0bd63-351a-4b72-87c2-b62ba53533cc","type":"PanTool"},{"id":"629c72bf-0d54-4399-8d8b-ff59067c5d1a","type":"WheelZoomTool"},{"id":"605d80b4-0fb1-42e5-8aa5-f8d73cbc5753","type":"BoxZoomTool"},{"id":"e4283761-22be-41e1-87c1-fa3b353354a9","type":"SaveTool" ...

# %%
# activate your slider!
interact(slider3, param=(0,750,1))

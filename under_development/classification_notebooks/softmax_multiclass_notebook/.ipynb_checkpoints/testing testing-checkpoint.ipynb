# %%
# %matplotlib inline
import convex_newt_surrogate
convex_newt_surrogate.run(w0 = -1, max_its = 10)

# %%
# %matplotlib inline
import nonconvex_newt_surrogate
nonconvex_newt_surrogate.run(w0 = 0.3, max_its = 4)

# %%
import numpy as np
w = np.linspace(-10,10)
g = w**4 + w**2 + w
plt.plot(w,g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-77e039354806> in <module>()
#       2 w = np.linspace(-10,10)
#       3 g = w**4 + w**2 + w
# ----> 4 plt.plot(w,g)
#
# NameError: name 'plt' is not defined

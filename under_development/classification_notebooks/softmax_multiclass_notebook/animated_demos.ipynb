# %% [markdown]
# # current animations

# %%
# %matplotlib inline
import gradient_descent_demo_1
import gradient_descent_demo_2
import student_debt_wrapper
import animated_linear_2class_demo
import animated_nonlinear_2class_demo
import convex_newt_surrogate
import nonconvex_newt_surrogate

# %% [markdown]
# Gradient descent examples

# %%
gradient_descent_demo_1.run(w0 = -10, alpha = 0.25, max_its = 20)

# %%
gradient_descent_demo_2.run(w0 = 0.5, alpha = 0.003, max_its = 50)

# %% [markdown]
# Newton's method examples

# %%
convex_newt_surrogate.run(w0 = -1, max_its = 5)

# %%
nonconvex_newt_surrogate.run(w0 = 0.3, max_its = 4)

# %% [markdown]
# regression examples

# %%
student_debt_wrapper.run()

# %% [markdown]
# classification examples

# %%
animated_linear_2class_demo.run(dataset = '2class_data.csv')

# %% [markdown]
# Nonlinear classification example

# %%
# note - poly feature transform faster (= better coded = taken from scikit-learn) than fourier or random
animated_nonlinear_2class_demo.run(dataset = '4eggs_data.csv',feat_type = 'poly', degree = 4)

# %% [markdown]
# # kernel and neural net space warping demos
#
# These slider toys shows how kernels and neural networks warp the underlying space of a dataset to tackle a prototypical nonlinear classification problem.  With these demonstrations you can play around and make any sort of nonlinear transformation rules you want and see how they warp space!
#
# This manner of visualizing how a neural network / kernel warps its input space complements the function or basis-view of neural networks described in Chapters 5-7 of the text.  The space is legally warped so that - in the transformed space - the two classes become linearly separable.
# This is a fundamental concept: nonlinear separation in the original data space corresponds one-to-one with linear separation in the transformed feature space (as illustrated in e.g., example 4.7 of the text).
#
# >The content of this notebook is supplementary material for the textbook Machine Learning Refined (Cambridge University Press, 2016). Visit http://www.mlrefined.com for free chapter downloads and tutorials, and [our Amazon site here](https://www.amazon.com/Machine-Learning-Refined-Foundations-Applications/dp/1107123526/ref=sr_1_1?ie=UTF8&qid=1474491657&sr=8-1&keywords=machine+learning+refined) for details regarding a hard copy of the text.
#
# Make sure to run the first Python cell below to load in all the necessary libraries for this demonstration.

# %%
# a necessary library for writing out our transform rules mathematically
from sympy import symbols, lambdify, sin, cos, tanh, exp, log, Max, Piecewise, And
from ipywidgets import interact
import sys
sys.path.append('demo_python_backend_files')

# our home-made warper 
import new_warper as warper
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="459bb79f-2ec0-47f4-89a5-8173ffa16ee2">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Space warping with a kernel
#
# Run the Python cells below to see how a basic kernel warps the underlying space of a dataset in order to correctly determine nonlinear separation.
#
# *Slowly* move this slider from left to right to see how the underlying space of this dataset is warped.  Gridlines are plotted in light gray to help you keep track of the transformations taking place.  Pushing the slider all the way to the right will show the complete transformation - in this space the dataset is perfectly linearly separable.
#
# **Note:** if you are not using a Docker image of this repo make sure you have installed the [bokeh](http://bokeh.pydata.org/en/latest/) plotting library in order to see this slider animation.

# %%
# make instance of warper
demo1 = warper.warp_demo()
x1,x2 = symbols('x1 x2')

# define your own rules here using elementary functions like sin, cos, tanh, sinc, or any polynomial combination of x1 and x2
rule1 = x1*x1 - 4
rule2 = x2*x2 - 4

# these two lines feed the transformation rules into the warping function and produce a toy dataset based on them
demo1.define_rule(rule1,rule2)
demo1.make_pts()

# this line creates an instance of the slider -  if you do not have bokeh installed you can use the demo1.transformation_slider - this uses matplotlib as the backend (and is considerably slower)
slider1 = demo1.bokeh_transformation_slider()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0013cb38-106c-4fa7-aa19-e24e1321f7a2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0013cb38-106c-4fa7-aa19-e24e1321f7a2").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("335f428b-afa7-4aef-9a58-3ace854e7df5", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0013cb38-106c-4fa7-aa19-e24e1321f7a2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0013cb38-106c-4fa7-aa19-e24e1321f7a2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"efbe34ec-f1c6-4b0e-8824-8cea50390d39":{"roots":{"references":[{"attributes":{"line_color":{"value":"#D3D3D3"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"04326aeb-b858-4429-b332-8bb7b9cff56a","type":"MultiLine"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"8a1ab0c3-ea66-4a6d-95db-d70616ee541a","subtype":"Figure","type":"Plot"},"ticker":{"id":"57908fdc-3250-40b8-9ce3-f759f29c94ab","type":"BasicTicker"}},"id":"b1ae7f3c-6b3f-4030-96b6-8351223424a1","type":"Grid"},{"attributes":{"callback":null,"column_names":["ys","xs"],"data":{"xs":[{"__ndarray__":"...","dtype":"float64","shape":[561]}],"ys":[{"__ndarray__":"...","dtype":"float64","shape":[561]}]}},"id":"7c60e36d-0e16-4a51-8f43-29d4a135d3bc","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#00FF7F"},"line_color":{"value":"#000000"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"28c4f17e-64ae-4deb-9048-1b4df71fd187","type":"Circle"},{"attributes":{"below":[{"id":"99c468b4-9331-4783-934c-17905d45f1f7","type":"LinearAxis"}],"left":[{"id":"7840a8ae-817f-4930-9562-95563600bfca","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"99c468b4-9331-4783-934c-17905d45f1f7","type":"LinearAxis"},{"id":"b1ae7f3c-6b3f-4030-96b6-8351223424a1","type":"Grid"},{"id":"7840a8ae-817f-4930-9562-95563600bfca","type":"LinearAxis"},{"id":"4eb0332c-1cb9-4bf0-b787-65e5e32ef896","type":"Grid"},{"id":"d3484f0d-95f1-4575-9557-d4a959aa6985","type":"BoxAnnotation"},{"id":"058a55ba-6f7c-4675-b0ef-f37137e0ecd5","type":"GlyphRenderer"},{"id":"cbf65800-14ff-49a1-995b-74ed8af8e058","type":"GlyphRenderer"},{"id":"faf19b78-2be0-41a9-a6d5-ce533b603d3a","type":"GlyphRenderer"},{"id":"fee5d11e-9ecb-496c-a41f-8a330b2cd087","type":"GlyphRenderer"}],"title":{"id":"221a1d5f-175e-4dc6-bd86-726b334e14a8","type":"Title"},"tool_events":{"id":"d6d105b1-82b6-4b26-8bf0-b30a68759e03","type":"ToolEvents"},"toolbar":{"id":"3c45dff6-8c95-4eaa-99b7-81bce6ffcaa9","type":"Toolbar"},"x_range":{"id":"49bfc18c-98bf-4bf3-8c43-219d6d47344e","type":"Range1d"},"y_range":{"id":"7ce397c5-e8f9-47ec-a06b-ba50c47ffa6e","type":"Range1d"}},"id":"8a1ab0c3-ea66-4a6d-95db-d70616ee541a","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"659d8d77-313f-4422-b707-be4c638cb6e2","type":"ColumnDataSource"},"glyph":{"id":"7cf63bee-5724-4617-bbfd-639917dfff60","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"42176f8b-1579-4b8f-96fd-29aefce72692","type":"Circle"},"selection_glyph":null},"id":"cbf65800-14ff-49a1-995b-74ed8af8e058","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7c60e36d-0e16-4a51-8f43-29d4a135d3bc","type":"ColumnDataSource"},"glyph":{"id":"e7dd4e84-3502-4979-9d8d-19613da11a30","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"08cbba20-f5a3-428b-8c4e-bcc86c8dcd5f","type":"MultiLine"},"selection_glyph":null},"id":"fee5d11e-9ecb-496c-a41f-8a330b2cd087","type":"GlyphRenderer"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"8a1ab0c3-ea66-4a6d-95db-d70616ee541a","subtype":"Figure","type":"Plot"},"ticker":{"id":"61a24234-ea53-4cb7-9af1-62eb7bba6e94","type":"BasicTicker"}},"id":"4eb0332c-1cb9-4bf0-b787-65e5e32ef896","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"cec51ca4-8e11-43c2-ab32-13d700862a9a","type":"MultiLine"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"42176f8b-1579-4b8f-96fd-29aefce72692","type":"Circle"},{"attributes":{"data_source":{"id":"1566d5d4-a862-4a45-a5b2-e32b14a382e3","type":"ColumnDataSource"},"glyph":{"id":"04326aeb-b858-4429-b332-8bb7b9cff56a","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"cec51ca4-8e11-43c2-ab32-13d700862a9a","type":"MultiLine"},"s ...

# %%
# activate your slider!
interact(slider1, param=(0,750,1))

# %% [markdown]
# # Space warping with a neural network
#
# Run the Python cells below to see how a basic neural net warps the underlying space of a dataset in order to correctly determine nonlinear separation.
#
# *Slowly* move this slider from left to right to see how the underlying space of this dataset is warped.  Gridlines are plotted in light gray to help you keep track of the transformations taking place.  Pushing the slider all the way to the right will show the complete transformation - in this space the dataset is perfectly linearly separable.
#
# **Note:** if you are not using a Docker image of this repo make sure you have installed the [bokeh](http://bokeh.pydata.org/en/latest/) plotting library in order to see this slider animation.

# %%
# make instance of warper
demo2 = warper.warp_demo()
x1,x2 = symbols('x1 x2')

# define your own rules here using elementary functions like sin, cos, tanh, sinc, or any polynomial combination of x1 and x2
rule1 = tanh(x1 + x2 + tanh(x1))
rule2 = tanh(0.1*x1)

# these two lines feed the transformation rules into the warping function and produce a toy dataset based on them
demo2.define_rule(rule1,rule2)
demo2.make_pts()

# this line creates an instance of the slider -  if you do not have bokeh installed you can use the demo1.transformation_slider - this uses matplotlib as the backend (and is considerably slower)
slider2 = demo2.bokeh_transformation_slider()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="412a3dbc-8b7d-4f0c-bbdc-f5724f063cdf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("412a3dbc-8b7d-4f0c-bbdc-f5724f063cdf").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("e23f509e-c019-4455-bdfe-3dc4b6c81517", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("412a3dbc-8b7d-4f0c-bbdc-f5724f063cdf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '412a3dbc-8b7d-4f0c-bbdc-f5724f063cdf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e4c543e8-d799-481a-912f-215154c8643b":{"roots":{"references":[{"attributes":{"formatter":{"id":"fc7f7bb9-8156-420a-911d-6ccc3d01212d","type":"BasicTickFormatter"},"plot":{"id":"dda04b99-3ead-430a-9adb-b2ee996ca780","subtype":"Figure","type":"Plot"},"ticker":{"id":"0797a5c4-093e-4a7c-b8da-5b67fddfaa39","type":"BasicTicker"},"visible":false},"id":"17b03f99-a9e8-4dc2-a1f1-d721c1e008b7","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"707b7c08-92dd-4874-866e-c273bd704ed9","type":"MultiLine"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"dda04b99-3ead-430a-9adb-b2ee996ca780","subtype":"Figure","type":"Plot"},"ticker":{"id":"0797a5c4-093e-4a7c-b8da-5b67fddfaa39","type":"BasicTicker"}},"id":"ac533716-732f-4e0c-bdfe-2dec63a3111d","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"0692331c-866a-448d-891d-3930cd7dcae9","type":"MultiLine"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"1083f989-5cff-4b9c-8aff-d9fb567aa27d","type":"Circle"},{"attributes":{"fill_color":{"value":"#FF0080"},"line_color":{"value":"#000000"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"55ea9c90-654b-4236-89d3-1527193c65ef","type":"Circle"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"dda04b99-3ead-430a-9adb-b2ee996ca780","subtype":"Figure","type":"Plot"},"ticker":{"id":"7cddb882-5744-4882-a00d-b8d9ac558179","type":"BasicTicker"}},"id":"8275e5f9-fd3b-4929-b1ce-19b85d857fa5","type":"Grid"},{"attributes":{"data_source":{"id":"8bd896b8-539e-4372-8d6a-f30b60593414","type":"ColumnDataSource"},"glyph":{"id":"55ea9c90-654b-4236-89d3-1527193c65ef","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"7f06722e-1bba-4bad-a22e-37cf91c3d0b1","type":"Circle"},"selection_glyph":null},"id":"dd048f1a-33cc-4fdf-832b-5cb66f060554","type":"GlyphRenderer"},{"attributes":{},"id":"35051a79-a2b2-401e-b188-871c958b9783","type":"ToolEvents"},{"attributes":{"below":[{"id":"56439af3-5411-48e1-94fe-438a2bb85c89","type":"LinearAxis"}],"left":[{"id":"17b03f99-a9e8-4dc2-a1f1-d721c1e008b7","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"56439af3-5411-48e1-94fe-438a2bb85c89","type":"LinearAxis"},{"id":"8275e5f9-fd3b-4929-b1ce-19b85d857fa5","type":"Grid"},{"id":"17b03f99-a9e8-4dc2-a1f1-d721c1e008b7","type":"LinearAxis"},{"id":"ac533716-732f-4e0c-bdfe-2dec63a3111d","type":"Grid"},{"id":"f2cfacae-5ea0-4cfa-bcde-2662d519b77c","type":"BoxAnnotation"},{"id":"fb4f8bce-11be-49b8-9d39-1080e5ce0c5b","type":"GlyphRenderer"},{"id":"dd048f1a-33cc-4fdf-832b-5cb66f060554","type":"GlyphRenderer"},{"id":"02623dd0-0d43-4d04-a044-55ad5f9a6f88","type":"GlyphRenderer"},{"id":"83150f22-b405-49d0-a3be-921103013938","type":"GlyphRenderer"}],"title":{"id":"3e752dd2-4e6f-42c0-aacc-becc13703629","type":"Title"},"tool_events":{"id":"35051a79-a2b2-401e-b188-871c958b9783","type":"ToolEvents"},"toolbar":{"id":"37589256-18ad-42c5-9f75-15c51805683d","type":"Toolbar"},"x_range":{"id":"7c9485d2-67e9-4efd-a247-f51935ce163d","type":"Range1d"},"y_range":{"id":"f3d1c0ab-1492-42fc-9a69-7ebf95e9e9e1","type":"Range1d"}},"id":"dda04b99-3ead-430a-9adb-b2ee996ca780","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":5.2,"start":-5.2},"id":"f3d1c0ab-1492-42fc-9a69-7ebf95e9e9e1","type":"Range1d"},{"attributes":{},"id":"7cddb882-5744-4882-a00d-b8d9ac558179","type":"BasicTicker"},{"attributes":{"data_source":{"id":"b31b4ce4-3958-4981-9a7f-ed40c64aec0a","type":"ColumnDataSource"},"glyph":{"id":"7181e79e-56bc-4ca5-b2ba-409cd95a9724","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"0692331c-866a ...

# %%
# activate your slider!
interact(slider2, param=(0,750,1))

# %% [markdown]
# # BONUS SECTION: Space warping with a tree
#
# Run the Python cells below to see how a basic tree warps the underlying space of a dataset in order to correctly determine nonlinear separation.  This one can get quite crazy due to the way we are plotting the transformations!
#
# *Slowly* move this slider from left to right to see how the underlying space of this dataset is warped.  Gridlines are plotted in light gray to help you keep track of the transformations taking place.  Pushing the slider all the way to the right will show the complete transformation - in this space the dataset is perfectly linearly separable.
#
# **Note:** if you are not using a Docker image of this repo make sure you have installed the [bokeh](http://bokeh.pydata.org/en/latest/) plotting library in order to see this slider animation.

# %%
# make instance of warper
demo3 = warper.warp_demo()
x1,x2 = symbols('x1 x2')

# define your own rules here using elementary functions like sin, cos, tanh, sinc, or any polynomial combination of x1 and x2
rule1 = Piecewise(
    (-1, And(-1 < x1, x1 < 1)),
    (1, x1 > 1),
    (1, x1 < -1)
)
rule2 = Piecewise(
    (-1,And(-1 < x2, x2 < 1)),
    (1, x2 > 1),
    (1, x2 < -1)
)

# these two lines feed the transformation rules into the warping function and produce a toy dataset based on them
demo3.define_rule(rule1,rule2)
demo3.make_pts()

# this line creates an instance of the slider -  if you do not have bokeh installed you can use the demo1.transformation_slider - this uses matplotlib as the backend (and is considerably slower)
slider3 = demo3.bokeh_transformation_slider()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5b9cb693-17d0-4325-8f65-5bf79458847a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5b9cb693-17d0-4325-8f65-5bf79458847a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("f0f38d92-877b-40b2-bb51-9fba309706ab", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b9cb693-17d0-4325-8f65-5bf79458847a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b9cb693-17d0-4325-8f65-5bf79458847a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"51ea44ed-bcef-44be-bef2-a3caefed3d27":{"roots":{"references":[{"attributes":{"data_source":{"id":"5dce72a5-c0ac-41a9-92b3-e9095160cdb9","type":"ColumnDataSource"},"glyph":{"id":"b62565f1-6bc3-40dc-872f-f777678a7976","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"8cebd3b9-4a80-48d4-81a9-4b48e234de21","type":"MultiLine"},"selection_glyph":null},"id":"8e15f97b-f565-42e3-b1d2-424585f18086","type":"GlyphRenderer"},{"attributes":{},"id":"e8c878b2-0ce3-4ea6-8f62-4066c73b8a99","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"fe11ef5c-c729-4c87-90f8-34fd82e87ff9","type":"ColumnDataSource"},"glyph":{"id":"29d62d3d-5031-4fb3-a810-1cb713de2d59","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"6c6a0957-0b70-4bbf-9479-495b654b4ff5","type":"MultiLine"},"selection_glyph":null},"id":"4f3a43e6-bd48-423d-8aa9-1853c0477e5d","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#FF0080"},"line_color":{"value":"#000000"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"70d8e7f2-b760-412d-8fa1-dbfb56522408","type":"Circle"},{"attributes":{"plot":{"id":"e47804bd-4856-4f26-b001-dddf831c6c91","subtype":"Figure","type":"Plot"}},"id":"458fa81d-20bb-4fbf-adb6-27400071c8d0","type":"HelpTool"},{"attributes":{},"id":"75e6ca06-288c-4974-acf2-0703ab6451ac","type":"ToolEvents"},{"attributes":{"line_color":{"value":"#000000"},"line_width":{"value":5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"29d62d3d-5031-4fb3-a810-1cb713de2d59","type":"MultiLine"},{"attributes":{},"id":"40a91e3c-1174-4731-a780-6814e1c645d2","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"bd277d96-84c2-4eb4-8371-696140b97d58","type":"ColumnDataSource"},"glyph":{"id":"ca22de7d-e332-416b-8dd9-22b3457f0874","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"b9d0289a-19bb-4c8d-9b68-7646a5f67e40","type":"Circle"},"selection_glyph":null},"id":"e6964796-ab52-4634-abb6-dce5062db5f5","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e47804bd-4856-4f26-b001-dddf831c6c91","subtype":"Figure","type":"Plot"}},"id":"c4a0bd63-351a-4b72-87c2-b62ba53533cc","type":"PanTool"},{"attributes":{"formatter":{"id":"e8c878b2-0ce3-4ea6-8f62-4066c73b8a99","type":"BasicTickFormatter"},"plot":{"id":"e47804bd-4856-4f26-b001-dddf831c6c91","subtype":"Figure","type":"Plot"},"ticker":{"id":"07f22a88-96dd-4b67-acca-4bc2f6cdab32","type":"BasicTicker"},"visible":false},"id":"09bab45a-d10b-40ea-a569-28df6af179f0","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["ys","xs"],"data":{"xs":[{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]}],"ys":[{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]},{"__ndarray__":"...","dtype":"float64","shape":[450]}]}},"id":"fe11ef5c-c729-4c87-90f8-34fd82e87ff9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"b9d0289a-19bb-4c8d-9b68-7646a5f67e40","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"78421680-927b-4b13-998d-8090b4c55043","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c4a0bd63-351a-4b72-87c2-b62ba53533cc","type":"PanTool"},{"id":"629c72bf-0d54-4399-8d8b-ff59067c5d1a","type":"WheelZoomTool"},{"id":"605d80b4-0fb1-42e5-8aa5-f8d73cbc5753","type":"BoxZoomTool"},{"id":"e4283761-22be-41e1-87c1-fa3b353354a9","type":"SaveTool" ...

# %%
# activate your slider!
interact(slider3, param=(0,750,1))

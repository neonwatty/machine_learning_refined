# %% [markdown]
# # Neural network space warping demo
#
# Run the first python cell to see a two class dataset with nonlinear boundary given by a single hidden layer network with tanh activations.
#
# Run the second python cell and use the slider to see how this network warps the input space - starting the left in the original space and all the way to the right for the feature space given by each hidden unit.

# %%
# load in subdirectories containing python files
import sys
sys.path.append('files')
# %matplotlib inline

# you can find the nnet_space_warp_v1.py class in the /files subdirectory
from nnet_space_warp_v1 import show_net_transform
test = show_net_transform()
test.plot_pts(test.X,test.rule)

# %%
# adjust the slider from left to right to see how the network warps the underlying space, and the points along with it
test.show_transform()

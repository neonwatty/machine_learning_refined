# %% [markdown]
# This notebook contains a simple slider mechanism for playing around with a time series prediction.  The training here is done via linear regression.  Training, prediction, plotting, and the slider mechanism functions are in the class MySeries2.

# %%
# load in myseries class, an input dataset, and train the model on this dataset
from MySeries2 import MySeries
# %matplotlib inline
predict_series = MySeries()
predict_series.load_data('apple_prices.csv')    # load in a csv - remember no header!
predict_series.train_model()                    # train the model to fit the data
predict_series.browse_vals()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
x = np.linspace(0,1,100)
y = np.exp(x)*np.cos(2*math.pi*np.sin(math.pi*x))
plt.plot(x,y)

# %%
num_pts = 39
noise_level = 0.25
inds = np.random.permutation(len(x))
x_data = x[inds[0:num_pts]]
y_data = y[inds[0:num_pts]] 
y_data = y_data + noise_level*np.random.randn(len(y_data),)
plt.scatter(x_data,y_data)
plt.plot(x,y)

# %%
from Function_Fit_Demo1 import Fit_Bases
import numpy as np
import math
# %matplotlib inline

# generate first function data
x = np.linspace(0,1,100)
y2 = np.sin(2*math.pi*x)


y1 = np.exp(x)*np.cos(2*math.pi*np.sin(math.pi*x))
y2 = np.sin(2*math.pi*x)
example = Fit_Bases()
example.load_data(x,y1)

# %%
example.browse_poly_fit()

# %%
example.browse_tree_fit()

# %%
example.browse_net_fit()

# %%
import numpy as np
import math
x = np.linspace(0,1,100)
x.shape = (len(x),1)
y = np.sin(2*math.pi*x)
y.shape = (len(y),1)
data = np.concatenate([x,y],axis = 1)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.DataFrame(data, index = None)

# %%
data.to_csv('sin_function.csv',index = None)

# %%
from Data_Fit_Demo1 import Fit_Bases
test = Fit_Bases()

# %%
test.load_data('noisy_sin_sample.csv')

# %%
test.load_target('sin_function.csv')

# %%
test.plot_all()

# %%
test.browse_poly_fit()

# %%
galileo_ramp_data.mat

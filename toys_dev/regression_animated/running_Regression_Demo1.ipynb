# %%
# %matplotlib inline
from Regression_Demo1 import Regression_Demo1
csvname = 'student_debt.csv'
test = Regression_Demo1()
test.load_data(csvname)
test.plot_pts()
test.make_cost_surface()

# %%
# %matplotlib inline
test.run_grad_descent(max_its = 20,inits = [0,-3],alpha = 0.0005)
# Out:
# 2.76306755254e-17 0.0794075245551

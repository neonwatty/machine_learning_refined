# %%
# %matplotlib inline
from Regression_Demo2 import Regression_Demo2
csvname = 'noisy_sin.csv'
test = Regression_Demo2()
test.load_data(csvname)
test.plot_pts()
test.make_cost_surface()

# %%
# %matplotlib inline
test.run_grad_descent(max_its = 35,inits = [4,5],alpha = 0.02)

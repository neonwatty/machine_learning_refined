# %% [markdown]
# Click anywhere in the right panel - which shows a contour plot of the least squares cost function - to select a parameter pair, and the corresponding line (in the left panel) will show up.  The chosen point is also shown in the middle panel - which is the cost function shown from an angle.

# %%
# %matplotlib nbagg
from Regression_Demo3 import Regression_Demo3
csvname = 'toy_regression_data.csv'
test = Regression_Demo3(csvname)
# Out:
# <img src="data:image/png;base64,...">

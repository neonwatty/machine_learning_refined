# %% [markdown]
# Short demo showing how boosting works at a high level - employing 1-dimensional stumps

# %%
# %matplotlib inline
from Boost_Demo1 import Boost_Demo1
booster = Boost_Demo1()
booster.load_data('noisy_sin_sample.csv')
booster.show_splitpoint(num_trees = 5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b3059f2e5f00> in <module>()
#       3 booster = Boost_Demo1()
#       4 booster.load_data('noisy_sin_sample.csv')
# ----> 5 booster.show_splitpoint(num_trees = 5)
#
# /Users/Nurgetson/mlrefined/toys_dev/decision_trees/Boost_Demo1.py in show_splitpoint(self, num_trees)
#     108
#     109                 # clear current figure
# --> 110                 display.display(plt.gcf())
#     111                 display.clear_output(wait=True)
#     112
#
# /Users/Nurgetson/anaconda2/lib/python2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     162             publish_display_data(data=obj, metadata=metadata)
#     163         else:
# --> 164             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     165             if not format_dict:
# ...
